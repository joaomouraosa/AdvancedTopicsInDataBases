# %% [markdown]
# ### Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.gridspec as gridspec
from matplotlib import cm
from matplotlib.animation import FuncAnimation
import psycopg2
import math
import datetime
import csv
import time
from postgis import Polygon,MultiPolygon
from postgis.psycopg import register
import trab_functions as aux
from importlib import reload
from ipywidgets import widgets
from IPython.display import HTML, display
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# %% [markdown]
# ### Definição de variáveis globais

# %% [markdown]
# ### Estabelecer uma ligação com a base de dados

# %%
starttime=time.time()
DEBUG=True
DBNAME='tracks'
USER='nan'
conn = psycopg2.connect("dbname=%s user=%s" % (DBNAME,USER))
register(conn)
cursor_psql = conn.cursor()

if DEBUG : print("took %f seconds" % (time.time()-starttime))
# Out:
# took 0.131668 seconds

# %% [markdown]
# ## Análise geral da tabela tracks<a name="análise"></a>

# %% [markdown]
# #### 2.1.1. Número de taxis

# %%
cursor_psql.execute('''SELECT COUNT(DISTINCT taxi) FROM tracks''')
results = cursor_psql.fetchall()
n_taxis= int(results[0][0])
print("Número de taxis: %d\n" % n_taxis)
# Out:
# Número de taxis: 1660

# %% [markdown]
# #### 2.1.2. Mostrar numero de trajetos que iniciaram a sua marcha a partir de que distritos

# %%
starttime=time.time()

cursor_psql.execute('''
                    SELECT distrito, count(*) 
                    FROM cont_aad_caop2018, tracks 
                    WHERE st_within(st_startpoint(proj_track),proj_boundary)
                    GROUP BY distrito ORDER BY 2 desc
                    ''')
results  = cursor_psql.fetchall()

display(HTML(
   '<table><tr>{}</tr></table>'.format(
       '</tr><tr>'.join(
           '<td>{}</td>'.format('</td><td>'.join(str(_) for _ in row)) for row in results)
       )
))

if DEBUG : print("took %f seconds" % (time.time()-starttime))
# Out:
# <table><tr><td>LISBOA</td><td>47945</td></tr><tr><td>PORTO</td><td>33835</td></tr><tr><td>COIMBRA</td><td>14127</td></tr><tr><td>BRAGA</td><td>4129</td></tr><tr><td>AVEIRO</td><td>2062</td></tr><tr><td>SETÚBAL</td><td>134</td></tr><tr><td>SANTARÉM</td><td>19</td></tr><tr><td>FARO</td><td>5</td></tr><tr><td>VIANA DO CASTELO</td><td>4</td></tr><tr><td>LEIRIA</td><td>1</td></tr></table>
# took 5.168290 seconds

# %% [markdown]
# #### 2.1.3. Mostrar numero de trajectos que terminaram a sua marcha em que distritos

# %%
starttime=time.time()

cursor_psql.execute('''
                    SELECT distrito, count(*) 
                    FROM cont_aad_caop2018, tracks 
                    WHERE st_within(st_endpoint(proj_track),proj_boundary)
                    GROUP BY distrito 
                    ORDER BY 2 desc
                    '''
)
fields = tuple([field[0] for field in cursor_psql.description])
results  = cursor_psql.fetchall()
results.insert(0,fields)

display(HTML(
   '<table><tr>{}</tr></table>'.format(
       '</tr><tr>'.join(
           '<td>{}</td>'.format('</td><td>'.join(str(_) for _ in row)) for row in results)
       )
))

if DEBUG : print("took %f seconds" % (time.time()-starttime))
# Out:
# <table><tr><td>distrito</td><td>count</td></tr><tr><td>LISBOA</td><td>47951</td></tr><tr><td>PORTO</td><td>33830</td></tr><tr><td>COIMBRA</td><td>14128</td></tr><tr><td>BRAGA</td><td>4132</td></tr><tr><td>AVEIRO</td><td>2065</td></tr><tr><td>SETÚBAL</td><td>125</td></tr><tr><td>SANTARÉM</td><td>19</td></tr><tr><td>FARO</td><td>5</td></tr><tr><td>VIANA DO CASTELO</td><td>3</td></tr></table>
# took 10.788102 seconds

# %% [markdown]
# ### Carregar o csv com os offsets, epidemia e calcular os histogramas

# %%
epidemic_array=["epidemic_without_immunity","epidemic_with_immunity"]
epidemic_menu = widgets.Dropdown(value=epidemic_array[0],options=epidemic_array,description='Epidemia')
widgets.VBox([epidemic_menu])
# Out:
# VBox(children=(Dropdown(description='Epidemia', options=('epidemic_without_immunity', 'epidemic_with_immunity'…

# %%
starttime=time.time()

OFFSETS_CSV='offsets3.csv'
EPIDEMIC_CSV=epidemic_menu.value + ".csv"
OFFSETS   = aux.read_offsets(OFFSETS_CSV)
infected  = aux.read_csv(EPIDEMIC_CSV)
histogram = aux.get_histograms(["PORTO","LISBOA","PORTUGAL"], infected, OFFSETS, cursor_psql)

if DEBUG : print("took %f seconds" % (time.time()-starttime))
# Out:
# took 38.092892 seconds

# %% [markdown]
# ### Animação no mapa de Portugal <a name="animação_país"></a>

# %% [markdown]
# ##### Pré-cálculo das dimensões do mapa de Portugal

# %%
starttime=time.time()

query = '''SELECT  min(st_xmin(proj_boundary)) as xmin, max(st_xmax(proj_boundary)) as xmax, 
                   min(st_ymin(proj_boundary)) as ymin, max(st_ymax(proj_boundary)) as ymax 
           FROM cont_aad_caop2018 '''

cursor_psql.execute(query)
results_pt = cursor_psql.fetchall()
xs_min_pt, xs_max_pt = results_pt[0][0], results_pt[0][1]
ys_min_pt, ys_max_pt = results_pt[0][2], results_pt[0][3]

width_in_inches_pt  = (xs_max_pt-xs_min_pt)/0.0254*1.1
height_in_inches_pt = (ys_max_pt-ys_min_pt)/0.0254*1.1
scale, ts_i = 1/3000000, 1570665600

query = ''' SELECT distrito,st_union(proj_boundary) FROM cont_aad_caop2018  GROUP BY distrito '''
cursor_psql.execute(query)
results_pt = cursor_psql.fetchall()

#mapear posicoes 0 0 com o valor 3 (branco)
for x in range(0,len(OFFSETS)):
    for y in range(0,len(OFFSETS[x])):
        if(OFFSETS[x][y][0]==0 and OFFSETS[x][y][1]==0):
            infected[x][y]=float(3)
color_data = np.array(infected)

if DEBUG : print("took %f seconds" % (time.time()-starttime))
# Out:
# took 31.896255 seconds

# %% [markdown]
# #### Animação

# %%
# %matplotlib notebook

plt.rcParams['figure.facecolor'] = '#F2F2F2'
cmap = ListedColormap(["green", "red", "blue","white"])

fig= plt.figure(figsize=(2*width_in_inches_pt*scale , height_in_inches_pt*scale)) 

gs = gridspec.GridSpec(3, 2)

pt_map1 = plt.subplot(gs[0:3, 0])
pt_map1.axis('off')
pt_map1.set(xlim=(xs_min_pt, xs_max_pt), ylim=(ys_min_pt, ys_max_pt))
fig.add_subplot(pt_map1)

labels, ax = ["PORTUGAL", "PORTO", "LISBOA"], []
for i in range(0,len(labels)):
    ax.append(plt.subplot(gs[i,1]))
    fig.add_subplot(ax[i])

    
scat = pt_map1.scatter([x[0] for x in OFFSETS[0]], [y[1] for y in OFFSETS[0]],
                       c=[1]*1660, s=2, cmap=cmap, vmin=0, vmax=3)

aux.show_map(results_pt,pt_map1)

k=0
index_i=1
speed=1
def animate(i):
    global index_i
    k=int(slider.value)
    index_i=int(k/120)

    pt_map1.set_title(datetime.datetime.utcfromtimestamp(ts_i+k*10))
    
    if(i%120==0):
        
        xx = [i for i in range(0,index_i+1)]
        for j in range(0,len(labels)):
            ax[j].clear()
            total_S= histogram[labels[j]]["total"]["S"][index_i]
            total_I= histogram[labels[j]]["total"]["I"][index_i]
            total_R= histogram[labels[j]]["total"]["R"][index_i]

            ax[j].set_title("Evolução dos casos - %s" % labels[j], x=0.5, y=.97,fontsize= 10)
            ax[j].set_ylabel("%")
            ax[j].set_xticks(np.arange(0, 72, 9))
            ax[j].set_xticklabels(np.array([str(x)+"h" for x in range(0,24,3)]))
            ax[j].xaxis.set_label_coords(1.05, -0.025)            
            ax[j].plot(xx,histogram[labels[j]]["perc"]["S"][0:index_i+1],color='green',label='S: %d'%total_S)
            ax[j].plot(xx,histogram[labels[j]]["perc"]["I"][0:index_i+1],color='red',label='I: %d'%total_I)
            ax[j].plot(xx,histogram[labels[j]]["perc"]["R"][0:index_i+1],color='blue',label='R: %d'%total_R)
            ax[j].legend(loc='upper right', frameon=False, fontsize=8,bbox_to_anchor=(1.27, 1))
        index_i+=1
    scat.set_array(color_data[k])
    scat.set_offsets(OFFSETS[k])
    k+=1
    slider.value=k

anim = FuncAnimation(fig, animate, interval=1, frames=len(OFFSETS)-1, repeat=True)

plt.show()
slider = widgets.IntSlider(value=0, min=0, max=len(OFFSETS)-1, step=1, description='', disabled=False, 
    continuous_update=True, orientation='horizontal')

start_button = widgets.Button(description='pause',disabled=False,button_style='success',icon='pause')

def event(button):
    if (button.description in ['start', 'resume']):
        anim.event_source.start()
        start_button.description='pause'
        start_button.icon='pause'
    else:
        anim.event_source.stop()
        start_button.description='resume' 
        start_button.icon='play'
   
start_button.on_click(event)
widgets.HBox([start_button, slider])
# Out:
# <img src="data:image/png;base64,..." width="812">
# HBox(children=(Button(button_style='success', description='pause', icon='pause', style=ButtonStyle()), IntSlid…

# %% [markdown]
# ### Com o outline dos distritos a mudar de cor

# %% [markdown]
# ##### Pré-cálculo dos distritos infectados ao longo do tempo

# %%
starttime=time.time()
    
dist = aux.distritos_infetados(infected, OFFSETS, cursor_psql)

if DEBUG : print("took %f seconds" % (time.time()-starttime))
# Out:
# took 147.375814 seconds

# %% [markdown]
# ##### Animação

# %%
plt.rcParams['figure.facecolor'] = '#F2F2F2'
cmap = ListedColormap(["green", "red", "blue","white"])

fig= plt.figure(figsize=(2*width_in_inches_pt*scale , height_in_inches_pt*scale)) 

gs = gridspec.GridSpec(3, 2)

pt_map1 = plt.subplot(gs[0:3, 0])
pt_map1.axis('off')
pt_map1.set(xlim=(xs_min_pt, xs_max_pt), ylim=(ys_min_pt, ys_max_pt))
fig.add_subplot(pt_map1)

labels, ax = ["PORTUGAL", "PORTO", "LISBOA"], []
for i in range(0,len(labels)):
    ax.append(plt.subplot(gs[i,1]))
    fig.add_subplot(ax[i]) 

scat = pt_map1.scatter([x[0] for x in OFFSETS[0]], [y[1] for y in OFFSETS[0]],
                       c=[1]*1660, s=2, cmap=cmap, vmin=0, vmax=3)

aux.show_map(results_pt,pt_map1)

k=0
index_i=1
speed=1
def animate(i):
    global k
    global index_i
    index_i=int(k/120)

    pt_map1.set_title(datetime.datetime.utcfromtimestamp(ts_i+k*10))
    
    if(i%120==0):
        xx = [i for i in range(0,index_i+1)]
        for j in range(0,len(labels)):
            ax[j].clear()
            total_S= histogram[labels[j]]["total"]["S"][index_i]
            total_I= histogram[labels[j]]["total"]["I"][index_i]
            total_R= histogram[labels[j]]["total"]["R"][index_i]

            ax[j].set_title("Evolução dos casos - %s" % labels[j], x=0.5, y=.97,fontsize= 10)
            ax[j].set_ylabel("%")
            ax[j].set_xticks(np.arange(0, 72, 9))
            ax[j].set_xticklabels(np.array([str(x)+"h" for x in range(0,24,3)]))
            ax[j].xaxis.set_label_coords(1.05, -0.025)            
            ax[j].plot(xx,histogram[labels[j]]["perc"]["S"][0:index_i+1],color='green',label='S: %d'%total_S)
            ax[j].plot(xx,histogram[labels[j]]["perc"]["I"][0:index_i+1],color='red',label='I: %d'%total_I)
            ax[j].plot(xx,histogram[labels[j]]["perc"]["R"][0:index_i+1],color='blue',label='R: %d'%total_R)
            ax[j].legend(loc='upper right', frameon=False, fontsize=8,bbox_to_anchor=(1.27, 1))
        aux.update_map(dist,pt_map1,index_i)
        index_i+=1
    scat.set_array(color_data[k])
    scat.set_offsets(OFFSETS[k])
    k+=1

anim = FuncAnimation(fig, animate, interval=1, frames=len(OFFSETS)-1, repeat=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="812">

# %% [markdown]
# ## Animação da epidemia em diferentes distritos <a name="animação_distrítos"></a>

# %% [markdown]
# #### Seleccionar um Distrito, intervalo de tempo e escala

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

query = '''
        SELECT DISTINCT distrito 
        FROM cont_aad_caop2018
        ORDER BY 1 asc
        '''
cursor_psql.execute(query)
results  = cursor_psql.fetchall()
distritos = [d[0] for d in results]

distritos_menu = widgets.Dropdown(value=distritos[0],options=distritos,description='Distrito')
horas_slider = widgets.IntRangeSlider(value=(10, 14), min=0, max=23, step=1, description='Intervalo (h)')

widgets.VBox([distritos_menu,horas_slider])
# Out:
# VBox(children=(Dropdown(description='Distrito', options=('AVEIRO', 'BEJA', 'BRAGA', 'BRAGANÇA', 'CASTELO BRANC…

# %% [markdown]
# ##### Pré-cálculo do mapa do distrito

# %%
""" Carregar os valores de input """
distrito=distritos_menu.value
(hora_inicial, hora_final) = horas_slider.value
scale=1/500000

starttime=time.time()

query='''
        SELECT 
            distrito, st_union(proj_boundary) as pol, 
            min(st_xmin(proj_boundary)) as xmin, 
            max(st_xmax(proj_boundary)) as xmax, 
            min(st_ymin(proj_boundary)) as ymin, 
            max(st_ymax(proj_boundary)) as ymax 
        FROM cont_aad_caop2018 WHERE distrito='%s'
        GROUP BY distrito
 ''' % distrito


cursor_psql.execute(query)
results  = cursor_psql.fetchall()

xs_min, xs_max, ys_min, ys_max = results[0][2], results[0][3], results[0][4], results[0][5]
width_in_inches  = (xs_max-xs_min)/0.0254*1.1
height_in_inches = (ys_max-ys_min)/0.0254*1.1

# %% [markdown]
# ### Mostrar a animação

# %%
# %matplotlib notebook
plt.rcParams['figure.facecolor'] = '#F2F2F2'

ts_hora_i = ts_i+3600*hora_inicial
ts_hora_f = ts_i+3600*hora_final

fig= plt.figure(figsize=(width_in_inches*scale , height_in_inches*scale)) 

gs = gridspec.GridSpec(1, 1)

mapa_distrito = plt.subplot(gs[0, 0])
mapa_distrito.axis('off')
mapa_distrito.set(xlim=(xs_min, xs_max), ylim=(ys_min, ys_max))

fig.add_subplot(mapa_distrito) 
aux.show_map(results,mapa_distrito)

scat = mapa_distrito.scatter([x[0] for x in OFFSETS[0]], [y[1] for y in OFFSETS[0]],
                       c=[1]*1660, s=2, cmap=cmap, vmin=0, vmax=3)
k=0
def animate(i):
    k=slider.value
    mapa_distrito.set_title(distrito + " @ " + str(datetime.datetime.utcfromtimestamp(ts_hora_i+k*10)))
    if(k>=(hora_final-hora_inicial)*360):
        anim.event_source.stop()    

    scat.set_array(color_data[k+hora_inicial*360])
    scat.set_offsets(OFFSETS[k+hora_inicial*360])
    anim.event_source.interval=10-speed_button.value*10+1
    k+=1
    slider.value=k

anim = FuncAnimation(fig, animate, interval=1, frames=len(OFFSETS)-1, repeat = True)

start_button = widgets.Button(description='pause',disabled=False,button_style='success',icon='pause')
zoom_in_button = widgets.Button(description='Zoom_in',disabled=False,button_style='info',icon='search-plus')
zoom_out_button = widgets.Button(description='Zoom_out',disabled=False,button_style='info',icon='search-minus')
speed_button= widgets.FloatSlider(value=.5, min=0,  max=1, step=0.1, description='Speed:', disabled=False,
    continuous_update=False,    orientation='horizontal',  readout=True,   readout_format='f')
slider = widgets.IntSlider(value=0, min=0, max=(hora_final-hora_inicial)*360, step=1, description='', disabled=False, 
    continuous_update=True, orientation='horizontal')

def event(button):
    if (button.description in ['start', 'resume']):
        anim.event_source.start()
        start_button.description='pause'
        start_button.icon='pause'
    else:
        anim.event_source.stop()
        start_button.description='resume' 
        start_button.icon='play'
   
def zoom_event(button):
    global scale
    if button.description=="Zoom_in": 
        scale+=1/10000000
    else:                               
        scale-=1/10000000
    fig.set_size_inches(width_in_inches*scale, height_in_inches*scale, forward=True)


if DEBUG: print("took %d seconds" % (time.time()-starttime))   
    
start_button.on_click(event)
zoom_in_button.on_click(zoom_event)
zoom_out_button.on_click(zoom_event)
widgets.HBox([slider,start_button, zoom_in_button, zoom_out_button])
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib64/python3.7/site-packages/matplotlib/cbook/__init__.py", line 196, in process
#     func(*args, **kwargs)
#   File "/usr/local/lib64/python3.7/site-packages/matplotlib/animation.py", line 1467, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="661">
# took 9 seconds
# HBox(children=(IntSlider(value=0, max=1440), Button(button_style='success', description='pause', icon='pause',…

# %% [markdown]
# ##### Percursos

# %%
# %matplotlib notebook

from matplotlib.colors import ListedColormap, LinearSegmentedColormap 
cmap = ListedColormap(["lawngreen", "blue", "red","white"])
plt.rcParams['figure.facecolor'] = '#303030'


ts_hora_i = ts_i+3600*hora_inicial
ts_hora_f = ts_i+3600*hora_final


fig= plt.figure(figsize=(width_in_inches*scale , height_in_inches*scale)) 

gs = gridspec.GridSpec(1, 1)

mapa_distrito = plt.subplot(gs[0, 0])
mapa_distrito.axis('off')
mapa_distrito.set(xlim=(xs_min, xs_max), ylim=(ys_min, ys_max))

fig.add_subplot(mapa_distrito) 

aux.show_map(results,mapa_distrito, "#D3D3D3")

xx,yy=[],[]
for i in OFFSETS[0]:
    xx.append(i[0])
    yy.append(i[1])

colors_=[]
offsets_=[]
pos_=[]
scat = mapa_distrito.scatter(xx,yy,color="white",s=.5,alpha=.2)

x_=[]
y_=[]

def animate(i):
    str_ = distrito + " @ " + str(datetime.datetime.utcfromtimestamp(ts_hora_i+i*10))
    mapa_distrito.set_title(str_, color='white')
    anim.event_source.interval=speed_button.value

    if(i>=(hora_final-hora_inicial)*360):  
        anim.event_source.stop()
    
    if (i%6==0): #minuto a minuto
        pos_=[]
        for j in range(0,len(OFFSETS[i+hora_inicial*360])):
            pos = OFFSETS[i+hora_inicial*360][j]
            if (pos[0]>=xs_min and xs_max>=pos[0] and pos[1]>=ys_min and ys_max>=pos[1]):
                offsets_.append(pos)
        
        scat.set_offsets(offsets_)

anim = FuncAnimation(fig, animate, interval=1, frames=len(OFFSETS)-1, repeat = False)

start_button = widgets.Button(description='pause',disabled=False,button_style='success',icon='pause')
restart_button = widgets.Button(description='restart',disabled=False,button_style='info',icon='restart')
zoom_in_button = widgets.Button(description='zoom in',disabled=False,button_style='info',icon='search-plus')
zoom_out_button = widgets.Button(description='zoom out',disabled=False,button_style='info',icon='search-minus')
speed_button= widgets.IntSlider(value=10, min=1,  max=20, step=1, description='Speed:', disabled=False,
    continuous_update=False,    orientation='horizontal',  readout=True,   readout_format='d'
)

def event(button):
    if(button.description=='start'):
        anim.event_source.start()
        button.description='pause'
        button.icon='pause'
    elif(button.description=='pause'):
        anim.event_source.stop()
        button.description='start'
        button.icon='play'
    else:
        global scale
        if(button.description=='zoom in'):
            scale+=1/10000000
        else:
            scale-=1/10000000
        fig.set_size_inches(width_in_inches*scale, height_in_inches*scale, forward=True)

if DEBUG: print("took %d seconds" % (time.time()-starttime))   

start_button.on_click(event)
zoom_in_button.on_click(event)
zoom_out_button.on_click(event)
widgets.HBox([start_button, zoom_in_button, zoom_out_button, speed_button])
# Out:
# <img src="data:image/png;base64,..." width="661">
# took 26 seconds
# HBox(children=(Button(button_style='success', description='pause', icon='pause', style=ButtonStyle()), Button(…

# %% [markdown]
# ## Animação em concelhos específicos <a name="animação_concelhos"></a>

# %% [markdown]
# ### Escolher um concelho específico

# %%
distrito=distritos_menu.value
(hora_inicial, hora_final) = horas_slider.value

#query para obter concelhos
query = '''
        SELECT DISTINCT concelho, distrito 
        FROM cont_aad_caop2018
        WHERE distrito='%s'
        ORDER BY 1 asc
        ''' % (distrito)
cursor_psql.execute(query)
results  = cursor_psql.fetchall()
concelhos = [c[0] for c in results]

concelhos_menu = widgets.Dropdown(value=concelhos[0],options=concelhos,description='Concelho')
widgets.VBox([concelhos_menu])
# Out:
# VBox(children=(Dropdown(description='Concelho', options=('AMARANTE', 'BAIÃO', 'FELGUEIRAS', 'GONDOMAR', 'LOUSA…

# %% [markdown]
# ### Gerar o mapa do concelho usando a biblioteca osmnx

# %% [markdown]
# ##### Pré-cálculo do mapa do concelho e conversão do sistema de coordenadas

# %%
import matplotlib.pyplot as plt
import osmnx as ox 
from descartes import PolygonPatch
from shapely.geometry import Polygon, MultiPolygon
ox.config(log_console=True, use_cache=True)
ox.__version__
ts_i= 1570665600

starttime = time.time()

concelho=concelhos_menu.value

""" query para obter o centroide e distancia maxima ao centroide num concelho """

query = '''
         SELECT  st_astext(st_transform(centroid,4236)) as centroid, 
                 st_maxdistance(centroid,pol) as dist 
         FROM
         (
                SELECT pol, st_centroid(pol) as centroid
                    FROM (
                        SELECT concelho, st_union(proj_boundary) as pol 
                        FROM cont_aad_caop2018
                        WHERE concelho='%s'
                        GROUP BY concelho
                    ) as foo
        ) as foo2
        ''' % (concelho)
cursor_psql.execute(query)
results = cursor_psql.fetchall()
point = results[0][0]

#remove a substring POINT( no inicio da string e ) do fim da string
lon,lat = point[len('POINT('):-1].split(" ") 
lat = float(lat)
lon = float(lon)
distance = float(results[0][1])

G = ox.graph_from_point((lat,lon),distance=distance)   

""" converter as coordenadas projectadas no sistema 3763 para o sistema 4326 """
    
i=0
index_from=360*hora_inicial
index_to=360*hora_final
starttime=time.time()

import pyproj
proj = pyproj.Transformer.from_crs(3763, 4326, always_xy=True) 

offsets_4326 = []
for r in range(index_from,index_to):
    tmp=[]
    for c in range(0,len(OFFSETS[r])):
        if (OFFSETS[r][c][0]!=0):
            lat,lon = proj.transform(OFFSETS[r][c][0], OFFSETS[r][c][1])
            tmp.append([lat,lon])
        else:
            tmp.append(OFFSETS[r][c])
    offsets_4326.append(tmp)
    
if DEBUG : print(time.time()-starttime)
# Out:
# 18.865193128585815

# %% [markdown]
# ##### Animação

# %%
# %matplotlib notebook
cmap = ListedColormap(["green", "red", "blue", "white"])

starttime=time.time()

fig, ax = ox.plot_figure_ground(G, default_width=.5, network_type='drive_service', fig_length=7, 
                                dist=distance, show=False, close=False,edge_color="#D3D3D3", 
                                smooth_joints=True)

ts_hora_i, ts_hora_f = ts_i+3600*hora_inicial, ts_i+3600*hora_final
num_taxis=len(OFFSETS[0])

scat = ax.scatter([x[0] for x in OFFSETS[0]], [y[1] for y in OFFSETS[0]],c=[1]*1660, 
                  s=12, cmap=cmap, vmin=0, vmax=3, alpha=1)
def animate(i):
    k=int(slider.value)
    anim.interval=speed_button.value
    ax.set_title(concelho + ", " + distrito + " @ " + str(datetime.datetime.utcfromtimestamp(ts_hora_i+k*10)),
                 color="white")

    if(k>=(hora_final-hora_inicial)*360):
        anim.event_source.stop()
    scat.set_offsets(offsets_4326[k])
    scat.set_array(color_data[hora_inicial*360+k])
    k+=1
    slider.value=k
    
anim = FuncAnimation(fig, animate, interval=1, frames=len(offsets_4326)-1, repeat=True)

start_button = widgets.Button(description='pause',disabled=False,button_style='success',icon='pause')
slider = widgets.IntSlider(value=0, min=0, max=(hora_final-hora_inicial)*360, step=1, description='', disabled=False, 
    continuous_update=True, orientation='horizontal')

def event(button):
    if(button.description=='start'):
        anim.event_source.start()
        button.description='pause'
        button.icon='pause'
    elif(button.description=='pause'):
        anim.event_source.stop()
        button.description='start'
        button.icon='play'
        
start_button.on_click(event)
widgets.HBox([start_button,slider])
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib64/python3.7/site-packages/matplotlib/cbook/__init__.py", line 196, in process
#     func(*args, **kwargs)
#   File "/usr/local/lib64/python3.7/site-packages/matplotlib/animation.py", line 1467, in _stop
#     self.event_source.remove_callback(self._loop_delay)
# AttributeError: 'NoneType' object has no attribute 'remove_callback'
# <img src="data:image/png;base64,..." width="926">
# HBox(children=(Button(button_style='success', description='pause', icon='pause', style=ButtonStyle()), IntSlid…
